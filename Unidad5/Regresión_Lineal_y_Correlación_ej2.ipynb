# %% [markdown]
# <a href="https://colab.research.google.com/github/25041032-Jocelyn/PROBABILIDAD-Y-ESTADISTICA/blob/main/Unidad5/Regresi%C3%B3n_Lineal_y_Correlaci%C3%B3n_ej2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Probabilidad y Estádistica**
# ##**Unidad 5**
# #Facilitador: José Gabriel Rodriguez Rivas
# #Alumno: Jocelyn García Castañeda
# #**Relación Lineal y Correlación: Ejemplo 2**

# %%
from scipy.stats import pearsonr

publicidad = [2, 3, 5, 4, 11, 5]
ganancias = [20, 25, 34, 30, 40, 31]

coeficiente_correlacion, p_valor = pearsonr(publicidad, ganancias)

print("Coeficiente de correlación de Pearson: ", coeficiente_correlacion)
print("Valor p: ", p_valor)
# Out:
# Coeficiente de correlación de Pearson:  0.909090909090909
# Valor p:  0.012021036814425281
