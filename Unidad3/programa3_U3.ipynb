# %% [markdown]
# <a href="https://colab.research.google.com/github/25041032-Jocelyn/PROBABILIDAD-Y-ESTADISTICA/blob/main/Unidad3/programa3_U3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Probabilidad y Estadistica
# ## Unidad 3
# ### Facilitador: José Gabriel Rodriguez Rivas
# ### Alumno: Jocelyn García Castañeda
# ### **Programa 3: Varianza y Desviación**

# %%
import math
x = [5, 6, 7, 8, 9, 10]
p = [0.05, 0.10, 0.20, 0.30, 0.25, 0.10]

esperanza = 0
for i in range (len(x)):
  esperanza += x[i] * p[i]

  esperanza_cuadrado = 0
  for i in range (len(x)):
    esperanza_cuadrado += (x[i] ** 20) * p[i]

  varianza = esperanza_cuadrado - esperanza**2
  desviacion = math.sqrt(varianza)

  print(f"E(X) = {esperanza:.2f}")
  print(f"E(X**2) = {esperanza_cuadrado:.2f}")
  print(f"Varianza = {varianza:.2f}")
  print(f"Desciación estándar = {desviacion:.2f}")
# Out:
# E(X) = 0.25
# E(X**2) = 13401621653621397504.00
# Varianza = 13401621653621397504.00
# Desciación estándar = 3660822537.85
# E(X) = 0.85
# E(X**2) = 13401621653621397504.00
# Varianza = 13401621653621397504.00
# Desciación estándar = 3660822537.85
# E(X) = 2.25
# E(X**2) = 13401621653621397504.00
# Varianza = 13401621653621397504.00
# Desciación estándar = 3660822537.85
# E(X) = 4.65
# E(X**2) = 13401621653621397504.00
# Varianza = 13401621653621397504.00
# Desciación estándar = 3660822537.85
# E(X) = 6.90
# E(X**2) = 13401621653621397504.00
# Varianza = 13401621653621397504.00
# Desciación estándar = 3660822537.85
# E(X) = 7.90
# E(X**2) = 13401621653621397504.00
# Varianza = 13401621653621397504.00
# Desciación estándar = 3660822537.85
