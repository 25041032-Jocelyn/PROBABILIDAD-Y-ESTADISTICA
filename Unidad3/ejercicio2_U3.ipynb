# %% [markdown]
# <a href="https://colab.research.google.com/github/25041032-Jocelyn/PROBABILIDAD-Y-ESTADISTICA/blob/main/Unidad3/ejercicio2_U3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Probabilidad y Estádistica**
# ##**Unidad 3**
# #Facilitador: José Gabriel Rodriguez Rivas
# #Alumno: Jocelyn García Castañeda
# #**Ejercicio 2**

# %%
import numpy as np
import matplotlib.pyplot as plt
import math

# %%
premios = ['A', 'B', 'C', 'D']
x = np.array([0, 10, 20, 50])
p = np.array([0.50, 0.30, 0.15, 0.05])
print ("Suma de probabilidades: ", sum(p))
# Out:
# Suma de probabilidades:  1.0

# %%
plt.stem(x, p)
plt.title("Distribución de Probabilidad")
plt.xlabel("Premios en pesos")
plt.ylabel("Probabilidad")
plt.grid(True)
plt.show()

# %%
valor_esperado = 0
for i in range (len(x)):
  xi = x[i]
  pi = p[i]
  producto = xi * pi
  valor_esperado += producto
  print (f"x = {xi}, p = {pi}, x * p = {producto:.2f}")
print(f"\nValor esperado de E(X): {valor_esperado:.2f}")
# Out:
# x = 0, p = 0.5, x * p = 0.00
# x = 10, p = 0.3, x * p = 3.00
# x = 20, p = 0.15, x * p = 3.00
# x = 50, p = 0.05, x * p = 2.50
#
# Valor esperado de E(X): 8.50

# %%
esperanza = 0
for i in range (len(x)):
  esperanza += x[i] * p[i]
  esperanza_cuadrado = 0
  for i in range(len(x)):
    esperanza_cuadrado += (x[i] ** 2 * p[i])
varianza = esperanza_cuadrado - esperanza ** 2
desviacion = math.sqrt(varianza)

print(f"E(X) = {esperanza:.2f}")
print(f"E(X**2) = {esperanza_cuadrado:.2f}")
print(f"Varianza = {varianza:.2f}")
print(f"Desviación estándar = {desviacion:.2f}")
# Out:
# E(X) = 8.50
# E(X**2) = 215.00
# Varianza = 142.75
# Desviación estándar = 11.95

# %%
F = np.cumsum(p)
for xi, fi in zip(x, F):
  print(f"F({xi}) = {fi:.2f}")

  plt.step(x, F, where = 'post')
  plt.title("Función de Distribución Acumulada (FDA)")
  plt.xlabel("Monto en pesos")
  plt.ylabel("Probabilidad acumulada")
  plt.grid(True)
  plt.ylim(0, 1.05)
  plt.show()
# Out:
# F(0) = 0.50
# F(10) = 0.80
# F(20) = 0.95
# F(50) = 1.00

# %% [markdown]
# ##¿Qué significa el valor esperado en este contexto?
# -Si un solo jugador compra muchos boletos, en promedio ganara 8.50 por boleto
# ##¿El juego es favorable para el jugador?
# -Si el boleto cuesta menos de 8.50 si es favorable, si cuesta exactamente eso entonces es justo, pero si cuesta más ya no es conveniente.
