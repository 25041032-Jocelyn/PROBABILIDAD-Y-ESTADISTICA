# %% [markdown]
# <a href="https://colab.research.google.com/github/25041032-Jocelyn/PROBABILIDAD-Y-ESTADISTICA/blob/main/Unidad3/ejercicio1_U3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import math

# %%
x = [0, 1, 2, 3, 4, 5]
p = [0.10, 0.25, 0.30, 0.20, 0.10, 0.05]
print ("Suma de probabilidades: ", sum(p))
# Out:
# Suma de probabilidades:  1.0

# %%
plt.stem(x, p)
plt.title("Distribución de Probabilidad")
plt.xlabel("Número de células anormales (X)")
plt.ylabel("Probabilidad")
plt.grid(True)
plt.show()

# %%
valor_esperado = 0
for i in range (len(x)):
  xi = x[i]
  pi = p[i]
  producto = xi * pi
  valor_esperado += producto
  print(f"x = {xi}, p = {pi}, x * p = {producto:.2f}")

  print(f"\nValor esperado de E(X): {valor_esperado:.2f}")
# Out:
# x = 0, p = 0.1, x * p = 0.00
#
# Valor esperado de E(X): 0.00
# x = 1, p = 0.25, x * p = 0.25
#
# Valor esperado de E(X): 0.25
# x = 2, p = 0.3, x * p = 0.60
#
# Valor esperado de E(X): 0.85
# x = 3, p = 0.2, x * p = 0.60
#
# Valor esperado de E(X): 1.45
# x = 4, p = 0.1, x * p = 0.40
#
# Valor esperado de E(X): 1.85
# x = 5, p = 0.05, x * p = 0.25
#
# Valor esperado de E(X): 2.10

# %%
esperanza = 0
for i in range (len(x)):
  esperanza += x[i] * p[i]

  esperanza_cuadrado = 0.0

  for i in range (len(x)):

    esperanza_cuadrado += (x[i] ** 2 * p[i])

varianza = esperanza_cuadrado - esperanza **2

desviacion = math.sqrt(varianza)


print(f"E(X) = {esperanza:.2f}")
print(f"E(X**2) = {esperanza_cuadrado:.2f}")
print(f"Varianza = {varianza:.2f}")
print(f"Desviación estándar = {desviacion:.2f}")
# Out:
# E(X) = 2.10
# E(X**2) = 6.10
# Varianza = 1.69
# Desviación estándar = 1.30

# %%
import numpy as np

# %%
F = np.cumsum(p)
for xi, fi in zip(x, F):
  print(f"F({xi}) = {fi:.2f}")

  plt.step(x, F, where = 'post')
  plt.title("Función de Distribución Acumulada (FDA)")
  plt.xlabel("Número de células")
  plt.ylabel("Probabilidad acumulada")
  plt.grid(True)
  plt.ylim(0, 1.05)
  plt.show()
# Out:
# F(0) = 0.10
# F(1) = 0.35
# F(2) = 0.65
# F(3) = 0.85
# F(4) = 0.95
# F(5) = 1.00

# %% [markdown]
# ###¿Cuál es el promedio esperado de células anormales por muestra?
# -El promedio esperado es de 2.10
# ###¿Existe mucha variabilidad entre las muestras?
# -No son tan dispersas, pero si hay diferencias notables entre ellas
# ###¿Qué indica la función acumuladad sobre la probabilidad de encontrar un número bajo o alto de células anormales?
# -Hay un 65% de probabilidad de encontrar 2 o menos células anormales, solo un 15% de encontrar 4 o menos células y el valor más probable individualmente es de x = 2 o 30%
