# %% [markdown]
# <a href="https://colab.research.google.com/github/25041032-Jocelyn/PROBABILIDAD-Y-ESTADISTICA/blob/main/Unidad1/Practica_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Probabilidad y Estadistica
# ## Unidad 1
# ### Facilitador: José Gabriel Rodriguez Rivas
# ### Alumno: Jocelyn García Castañeda
# ### **Programa 1: Estadistica básica e Histogramas**

# %%
from statistics import *

# %%
# Lista de calificaciones del grupo A de probabilidad y estadistica
grupoa = [70, 70, 65, 90, 100, 95, 45, 80, 73, 20, 100, 96]
print(grupoa)
# Out:
# [70, 70, 65, 90, 100, 95, 45, 80, 73, 20, 100, 96]

# %%
# la funcion type nos devuelve el tipo de dato de la variable type
type (grupoa)
# Out:
# list

# %%
# Sacar la media de las calificaciones con una formula
promedio = sum(grupoa)/len(grupoa)
print(promedio)
# Out:
# 75.33333333333333

# %%
# Utilizar la funcion mean que esta en la libreria statistics para sacar el promedio
# el promedio:
promedio2 = mean (grupoa)
print(promedio2)
# Out:
# 75.33333333333333

# %%
# Determinar el valor de la mediana con la funcion mediam
mediana = median(grupoa)
print (mediana)
# Out:
# 76.5

# %%
# Determinar el valor de la moda con la funcion mode
moda = mode(grupoa)
print(moda)
# Out:
# 70

# %%
tiempos = [10.23, 15.20, 22.15, 11.49, 17.83, 16.30, 12.53, 13.55, 10.23, 14.56]
promedio = sum(tiempos)/len(tiempos)
mediana = median(tiempos)
moda = mode(tiempos)
print ("Los tiempos de los jugadores fueron: ", tiempos)
print ("El promedio de los tiempos es: ", promedio)
print ("La mediana de los tiempos es: ", mediana)
print ("La moda de los tiempos es: ", moda)
# Out:
# Los tiempos de los jugadores fueron:  [10.23, 15.2, 22.15, 11.49, 17.83, 16.3, 12.53, 13.55, 10.23, 14.56]
# El promedio de los tiempos es:  14.407
# La mediana de los tiempos es:  14.055
# La moda de los tiempos es:  10.23

# %%
#libreria para genarar numeros aleatorios
import random
fabrica1 = []
for i in range (100):
  numero_aleatorio = round( random.uniform(50, 100), 2)
  fabrica1.append(numero_aleatorio)
print (fabrica1)
# Out:
# [89.65, 72.33, 94.01, 67.92, 70.75, 62.83, 52.85, 96.89, 81.06, 98.4, 66.74, 53.38, 58.38, 52.4, 83.1, 83.62, 95.83, 62.81, 95.76, 85.94, 77.75, 77.67, 64.04, 53.65, 96.82, 92.56, 90.23, 86.48, 84.11, 54.36, 57.31, 62.05, 94.28, 96.61, 53.59, 94.67, 55.13, 59.16, 74.08, 77.1, 82.85, 52.77, 62.09, 88.28, 76.7, 90.12, 91.59, 82.58, 95.24, 55.67, 64.23, 51.1, 81.33, 52.59, 80.38, 79.04, 57.39, 54.45, 79.9, 64.62, 50.1, 98.62, 80.27, 91.55, 52.26, 75.58, 95.18, 64.38, 53.74, 54.0, 64.27, 77.17, 77.73, 93.55, 72.2, 65.75, 72.78, 96.94, 71.86, 71.02, 56.29, 53.0, 65.07, 71.0, 57.35, 67.36, 82.31, 70.58, 59.6, 74.01, 51.55, 53.16, 98.17, 92.26, 53.24, 96.15, 89.22, 99.87, 53.25, 73.34]

# %%
fabrica2 = []
for i in range (100):
  numero_aleatorio = round( random.uniform(70, 100), 2)
  fabrica2.append(numero_aleatorio)
print (fabrica2)
# Out:
# [77.56, 79.44, 80.52, 86.13, 99.39, 84.33, 81.02, 79.3, 78.76, 85.96, 75.15, 72.2, 83.02, 90.6, 72.81, 92.54, 94.99, 89.94, 77.5, 81.35, 77.89, 76.18, 71.4, 70.57, 85.68, 84.18, 75.13, 74.06, 87.56, 99.16, 78.59, 76.62, 82.55, 73.43, 81.04, 84.6, 96.97, 74.52, 86.11, 74.44, 73.59, 71.26, 97.33, 78.09, 96.45, 89.32, 84.64, 74.64, 74.72, 86.28, 80.09, 93.49, 99.04, 86.1, 93.45, 72.15, 70.51, 93.59, 83.22, 97.07, 72.78, 85.29, 91.31, 96.08, 95.52, 99.09, 93.15, 93.78, 84.68, 87.43, 78.43, 79.48, 76.05, 92.88, 74.91, 87.02, 85.64, 70.28, 93.78, 97.77, 91.74, 79.68, 87.18, 99.68, 88.54, 74.78, 74.76, 86.39, 86.01, 98.67, 81.61, 73.38, 77.88, 71.78, 75.44, 73.4, 96.21, 83.0, 89.6, 89.53]

# %%
#libreria de python para graficar variables
import matplotlib.pyplot as plt
plt.hist(fabrica1)
plt.title("Poducción diaria de la fabrica 1")
# Out:
# Text(0.5, 1.0, 'Poducción diaria de la fabrica 1')

# %%
plt.hist(fabrica2)
plt.title("Poducción diaria de la fabrica 2")
# Out:
# Text(0.5, 1.0, 'Poducción diaria de la fabrica 2')

# %%
media1 = mean (fabrica1)
mediana1 = median (fabrica1)
moda1 = mode (fabrica1)
print ("La media de la fabrica 1 es: ", media1)
print ("La mediana de la fabrica 1 es: ", mediana1)
print ("La moda de la fabrica 1 es: ", moda1)
# Out:
# La media de la fabrica 1 es:  81.06026666666666
# La mediana de la fabrica 1 es:  82.04499999999999
# La moda de la fabrica 1 es:  83.1

# %%
media2 = mean (fabrica2)
mediana2 = median (fabrica2)
moda2 = mode (fabrica2)
print ("La media de la fabrica 2 es: ", media2)
print ("La mediana de la fabrica 2 es: ", mediana2)
print ("La moda de la fabrica 2 es: ", moda2)
# Out:
# La media de la fabrica 2 es:  83.8283
# La mediana de la fabrica 2 es:  83.7
# La moda de la fabrica 2 es:  93.78
