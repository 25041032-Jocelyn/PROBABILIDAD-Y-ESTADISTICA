# %% [markdown]
# <a href="https://colab.research.google.com/github/25041032-Jocelyn/PROBABILIDAD-Y-ESTADISTICA/blob/main/Unidad4/ejercicio2%3ADistribuci%C3%B3n_Binomial_U4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Probabilidad y Estádistica**
# ##**Unidad 4**
# #Facilitador: José Gabriel Rodriguez Rivas
# #Alumno: Jocelyn García Castañeda
# #**Distribución Binomial: Ejercicio 2**

# %%
from scipy.stats import binom

# %%
n = 0
p = 0.10
x = 2

probabilidad_x_2 = binom.pmf(x, n, p)

print("La probabilidad de que la variable aleatoria X sea igual a 2 es:", probabilidad_x_2)
# Out:
# La probabilidad de que la variable aleatoria X sea igual a 2 es: 0.0
