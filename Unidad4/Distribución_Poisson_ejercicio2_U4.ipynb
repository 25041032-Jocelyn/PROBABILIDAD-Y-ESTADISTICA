# %% [markdown]
# <a href="https://colab.research.google.com/github/25041032-Jocelyn/PROBABILIDAD-Y-ESTADISTICA/blob/main/Unidad4/Distribuci%C3%B3n_Poisson_ejercicio2_U4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Probabilidad y Estádistica**
# ##**Unidad 4**
# #Facilitador: José Gabriel Rodriguez Rivas
# #Alumno: Jocelyn García Castañeda
# #**Distribución de Poisson: Ejercicio 2**

# %%
from scipy.stats import poisson

# %%
media_muertes = 5000 * 0.001

x = 4

probabilidad_4_reclamaciones = poisson.pmf(x, media_muertes)

print("La probabilidad de que la compañía tenga que pagar 4 reclamaciones es de: ",
      probabilidad_4_reclamaciones)
