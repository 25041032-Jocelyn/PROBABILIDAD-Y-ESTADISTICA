# %% [markdown]
# <a href="https://colab.research.google.com/github/25041032-Jocelyn/PROBABILIDAD-Y-ESTADISTICA/blob/main/Unidad4/ejercicio1%3ADistribuci%C3%B3n_Binomial_U4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Probabilidad y Estádistica**
# ##**Unidad 4**
# #Facilitador: José Gabriel Rodriguez Rivas
# #Alumno: Jocelyn García Castañeda
# #**Distribución Binomial: Ejercicio 1**

# %%
from scipy.stats import binom

# %%
#Parámetros de la distribución binomial
probabilidad_exito = 0.83
num_pacientes = 16
X = 16 #Número de éxitos

#Cálcular la rpobabilidad de que ningún paciente sufra la enfermedad
probabilidad_ninguno_enfermo = binom.pmf( X, num_pacientes, probabilidad_exito)

print("La probabilidad de que ningún paciente sufra la enfermedad es: ", probabilidad_ninguno_enfermo)
# Out:
# La probabilidad de que ningún paciente sufra la enfermedad es:  0.0507282029895386

# %%
probabilidad_exito = 0.83
num_pacientes = 16
X = 0

probabilidad_todos_enfermos = binom.pmf( X, num_pacientes, probabilidad_exito)

print("La probailidad de que todos los pacientes sufran la enfermedad es: ", probabilidad_todos_enfermos)
# Out:
# La probailidad de que todos los pacientes sufran la enfermedad es:  4.866119187566701e-13
