# %% [markdown]
# <a href="https://colab.research.google.com/github/25041032-Jocelyn/PROBABILIDAD-Y-ESTADISTICA/blob/main/Unidad4/programa1_U4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Probabilidad y Estádistica**
# ##**Unidad 4**
# #Facilitador: José Gabriel Rodriguez Rivas
# #Alumno: Jocelyn García Castañeda
# #**Programa 1: Distribución Normal**
