# %% [markdown]
# <a href="https://colab.research.google.com/github/25041032-Jocelyn/PROBABILIDAD-Y-ESTADISTICA/blob/main/Practica2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Probabilidad y Estadistica
# ## Unidad 1
# ### Facilitador: José Gabriel Rodriguez Rivas
# ### Alumno: Jocelyn García Castañeda
# ### **Programa 2: Máximo, minimo, rango y disperción de datos**

# %%
import random
import matplotlib.pyplot as plt
from statistics import *

# %%
#Generamos 100 numeros aleatorios que representen la producción en metros de la tela de 100 días
fabrica1 = []
for i in range(100):
    numero_aleatorio = round(random.uniform(50, 100), 2)
    fabrica1.append(numero_aleatorio)
print(fabrica1)
# Out:
# [87.92, 75.27, 88.31, 83.25, 72.38, 74.38, 93.84, 73.13, 82.56, 53.35, 61.95, 92.35, 68.15, 65.55, 52.38, 56.56, 98.9, 54.91, 64.76, 54.08, 82.77, 90.7, 58.04, 80.59, 66.38, 92.34, 50.25, 69.37, 71.69, 65.17, 90.76, 94.1, 67.4, 71.99, 89.39, 50.83, 55.13, 63.29, 72.88, 97.06, 97.74, 88.02, 57.19, 71.32, 80.63, 85.27, 96.48, 84.88, 68.28, 56.59, 55.35, 98.93, 66.19, 77.46, 80.65, 74.97, 84.31, 76.05, 82.13, 72.79, 82.12, 98.04, 78.26, 63.08, 98.86, 81.61, 54.07, 63.15, 56.99, 54.05, 94.14, 76.3, 82.59, 67.92, 53.41, 73.44, 79.17, 63.76, 83.49, 66.59, 80.11, 69.73, 64.34, 77.5, 84.71, 92.84, 82.49, 61.82, 90.65, 88.28, 69.61, 96.21, 64.71, 92.52, 67.3, 74.38, 84.24, 82.28, 85.32, 84.2]

# %%
maximo1 = max(fabrica1)
minimo1 = min(fabrica1)
rango1 = maximo1 - minimo1
media1 = mean(fabrica1)
mediana1 = median(fabrica1)
moda1 = mode(fabrica1)
desviacion_estandar_fabrica1 = stdev(fabrica1)
print("Estadistica descriptiva de la Fabrica 1 \n,", "Media =",media1,
      "\n Mediana =", mediana1, "\n Moda =", moda1, "\n Maximo =", maximo1,
      "\n Minimo =", minimo1, "\n Rango =", rango1)
print(desviacion_estandar_fabrica1)
# Out:
# Estadistica descriptiva de la Fabrica 1
# , Media = 75.5362
#  Mediana = 75.66
#  Moda = 74.38
#  Maximo = 98.93
#  Minimo = 50.25
#  Rango = 48.68000000000001
# 13.578140541534271

# %%
maximo2 = max(fabrica2)
minimo2 = min(fabrica2)
rango2 = maximo2 - minimo2
media2 = mean(fabrica2)
mediana2 = median(fabrica2)
moda2 = mode(fabrica2)
desviacion_estandar_fabrica2 = stdev(fabrica2)
print("Estadistica descriptiva de la Fabrica 2\n", "Media =", media2,
      "\n Mediana =", mediana2, "\n Moda =", moda2, "\n Maximo =", maximo2,
      "\n Minimo =", minimo2, "\n Rango =", rango2)
print("Desviación estándar:", desviacion_estandar_fabrica2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-498725389.py in <cell line: 0>()
# ----> 1 maximo2 = max(fabrica2)
#       2 minimo2 = min(fabrica2)
#       3 rango2 = maximo2 - minimo2
#       4 media2 = mean(fabrica2)
#       5 mediana2 = median(fabrica2)
#
# NameError: name 'fabrica2' is not defined
