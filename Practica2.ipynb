# %% [markdown]
# <a href="https://colab.research.google.com/github/25041032-Jocelyn/PROBABILIDAD-Y-ESTADISTICA/blob/main/Practica2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Probabilidad y Estadistica
# ## Unidad 1
# ### Facilitador: José Gabriel Rodriguez Rivas
# ### Alumno: Jocelyn García Castañeda
# ### **Programa 2: Máximo, minimo, rango y disperción de datos**

# %%
import random
import matplotlib.pyplot as plt
from statistics import *

# %%
#Generamos 100 numeros aleatorios que representen la producción en metros de la tela de 100 días
fabrica1 = []
for i in range(100):
    numero_aleatorio = round(random.uniform(50, 100), 2)
    fabrica1.append(numero_aleatorio)
print(fabrica1)
# Out:
# [77.51, 91.42, 51.76, 56.17, 66.9, 72.66, 80.72, 99.59, 84.16, 64.49, 96.37, 59.33, 76.36, 54.58, 69.3, 51.88, 66.26, 92.02, 98.66, 56.54, 87.78, 78.79, 81.72, 68.74, 62.74, 64.25, 69.6, 71.28, 86.01, 74.91, 67.77, 53.94, 79.41, 72.99, 61.43, 72.47, 63.9, 53.17, 75.47, 83.99, 97.99, 70.14, 81.77, 52.48, 56.42, 66.06, 79.42, 74.15, 51.04, 51.86, 53.38, 50.37, 75.02, 59.2, 57.01, 84.35, 97.63, 57.21, 54.11, 95.94, 77.73, 50.25, 64.24, 60.29, 82.41, 95.15, 85.93, 80.65, 66.25, 56.09, 62.86, 72.4, 87.25, 67.6, 51.58, 55.24, 96.84, 56.44, 90.39, 82.25, 92.39, 78.95, 72.25, 63.05, 79.83, 98.74, 59.47, 80.52, 68.52, 93.41, 79.33, 71.25, 55.99, 65.58, 80.19, 50.27, 50.8, 54.23, 52.49, 98.23]

# %%
maximo1 = max(fabrica1)
minimo1 = min(fabrica1)
rango1 = maximo1 - minimo1
media1 = mean(fabrica1)
mediana1 = median(fabrica1)
moda1 = mode(fabrica1)
desviacion_estandar_fabrica1 = stdev(fabrica1)
print("Estadistica descriptiva de la Fabrica 1 \n,", "Media =",media1,
      "\n Mediana =", mediana1, "\n Moda =", moda1, "\n Maximo =", maximo1,
      "\n Minimo =", minimo1, "\n Rango =", rango1)
print(desviacion_estandar_fabrica1)
# Out:
# Estadistica descriptiva de la Fabrica 1
# , Media = 71.4992
#  Mediana = 70.695
#  Moda = 77.51
#  Maximo = 99.59
#  Minimo = 50.25
#  Rango = 49.34
# 14.662453298383348

# %%
#Generamos 100 numeros aleatorios que representen la producción en metros de la tela de 100 días
fabrica2 = []
for i in range(100):
    numero_aleatorio = round(random.uniform(50, 100), 2)
    fabrica2.append(numero_aleatorio)
print(fabrica2)
# Out:
# [84.43, 99.49, 85.53, 61.63, 88.93, 73.89, 84.89, 81.64, 60.97, 50.28, 61.03, 58.3, 78.42, 69.29, 52.25, 94.13, 57.38, 88.57, 70.19, 95.01, 65.64, 84.06, 55.53, 63.38, 80.13, 86.49, 54.55, 82.14, 70.22, 52.29, 71.87, 77.9, 62.82, 99.96, 78.85, 65.26, 74.6, 57.52, 59.15, 73.49, 63.95, 76.72, 95.36, 91.38, 72.26, 70.76, 83.09, 79.08, 79.92, 54.05, 69.14, 67.6, 56.96, 73.41, 61.28, 89.07, 56.56, 58.32, 51.65, 74.17, 59.29, 68.46, 87.54, 94.04, 51.23, 89.35, 65.75, 84.85, 62.14, 76.44, 90.02, 64.17, 87.68, 96.2, 77.94, 52.41, 51.64, 94.57, 70.97, 77.58, 54.2, 69.69, 88.27, 65.08, 52.38, 76.93, 90.14, 86.74, 94.49, 96.12, 73.22, 99.04, 61.98, 55.84, 92.82, 99.64, 89.4, 54.06, 84.84, 98.05]

# %%
maximo2 = max(fabrica2)
minimo2 = min(fabrica2)
rango2 = maximo2 - minimo2
media2 = mean(fabrica2)
mediana2 = median(fabrica2)
moda2 = mode(fabrica2)
desviacion_estandar_fabrica2 = stdev(fabrica2)
print("Estadistica descriptiva de la Fabrica 2\n", "Media =", media2,
      "\n Mediana =", mediana2, "\n Moda =", moda2, "\n Maximo =", maximo2,
      "\n Minimo =", minimo2, "\n Rango =", rango2)
print("Desviación estándar:", desviacion_estandar_fabrica2)
# Out:
# Estadistica descriptiva de la Fabrica 2
#  Media = 74.2203
#  Mediana = 73.69
#  Moda = 84.43
#  Maximo = 99.96
#  Minimo = 50.28
#  Rango = 49.67999999999999
# Desviación estándar: 14.61666935869503
